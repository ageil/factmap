# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from keras.models import load_model
import matplotlib.pyplot as plt
import pickle
% matplotlib inline

import sys
sys.path.append("..")
from scripts.gen import DataGenerator
from scripts.rnn import singleRNN, dualRNN
# Out:
# Using TensorFlow backend.

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    
    fig, ax = plt.subplots(figsize=(10,6))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=0, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
with open('../data/word2token.pickle', 'rb') as f:
    word2token = pickle.load(f)
    
with open('../data/token2word.pickle', 'rb') as f:
    token2word = pickle.load(f)

# %%
with open('../data/embedding_matrix.pickle', 'rb') as f:
    embedding_matrix = pickle.load(f)

with open('../data/embedding_matrix_oov.pickle', 'rb') as f:
    embedding_matrix_oov = pickle.load(f)
    
with open('../data/embedding_matrix_inv.pickle', 'rb') as f:
    embedding_matrix_inv = pickle.load(f)

# %%
with open('../data/partition.pickle', 'rb') as f:
    partition = pickle.load(f)

gen_train = DataGenerator(partition, mode='train', all_text=True, train_oov=False, batch_size=1)
gen_valid = DataGenerator(partition, mode='valid', all_text=True, train_oov=False, batch_size=1)
gen_test = DataGenerator(partition, mode='test', all_text=True, train_oov=False, batch_size=1)
gen_test_id = DataGenerator(partition, mode='test', all_text=True, train_oov=False, batch_size=1, return_id=True)

# %%
rnn_single = singleRNN(embedding_matrix)
rnn_single.load_weights("../output/rc_tall/weights/epoch_004-valloss_0.11-valacc_0.97.hdf5")

# %%
def preds(model, generator):
    preds = model.predict_generator(generator)
    y_pred = preds.round().astype(int)
    
    y_true = np.empty(shape=(len(generator)), dtype=int)    
    for i in range(len(generator)):
        y_true[i] = generator.__getitem__(i)[1]
    
    return y_true, y_pred

def confmat(y_true, y_pred, normalize=False, savefile=None):
    plot_confusion_matrix(y_true, y_pred, classes=np.array(["Fact","Fake"]), normalize=normalize)
    if savefile:
        plt.savefig(savefile, bbox_inches='tight')
    plt.show()

# %%
y_true, y_pred = preds(model=rnn_single, generator=gen_test)

# %%
# confmat(y_true, y_pred, normalize=True, savefile='./cmat_tall.png')

# %%
# confmat(y_true, y_pred, normalize=False, savefile='./cmat_tall_abs.png')

# %% [markdown]
# Find examples of wrong predictions for progress presentation:

# %%
def printExample(ID):
    claim = partition['test'][ID]['claim']
    rating = partition['test'][ID]['rating']
    
    print("Claim:\n", ' '.join([token2word[t] for t in claim]))
    print("Rating:\n", ' '.join([token2word[t] for t in rating]))

# %%
for i in range(gen_test_id.__len__()):
    ID, data = gen_test_id.__getitem__(i)
    y_true = float(data[1])
    y_pred = float(rnn_single.predict(data[0]))
    if round(y_pred) != y_true and y_true == 0 and y_pred>0.9:
        print("Predicted:", y_pred)
        print("Actual:", y_true)
        print("ID:", ID)
        printExample(ID[0])
        print()
# Out:
# Predicted: 0.9906553626060486
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d70358b']
# Claim:
#  says department of justice does not disclose how many americans are on terrorist watch lists
# Rating:
#  false
#
# Predicted: 0.9393472075462341
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d70064f']
# Claim:
#  abigail spanberger would vote with pelosi for a 32 trillion government takeover of health care nearly doubling the debt
# Rating:
#  false
#
# Predicted: 0.9880837798118591
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6f88ce']
# Claim:
#  chuck schumer democrat senate minority leader accused of raping his daughter s 16 year old friend friend then 'committed suicide '
# Rating:
#  false
#
# Predicted: 0.9999980926513672
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6fdd0f']
# Claim:
#  on navigator those that according dimaio must accompany the unemployed to look for work had first to be 10 000 then 6000 now it is 3000
# Rating:
#  5
#
# Predicted: 0.9999880790710449
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d702ce4']
# Claim:
#  sarah palin in a coma after hit and run
# Rating:
#  pants on fire
#
# Predicted: 0.9809196591377258
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6fc9f5']
# Claim:
#  not giving 5 billion for joesley buy companies in the united states or argentina or giving to buy gerdau steel in colombia we will help this country
# Rating:
#  subestimado
#
# Predicted: 0.9979379773139954
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6f9a8c']
# Claim:
#  putting our miners back to work like never before going back back back
# Rating:
#  false
#
# Predicted: 0.9955665469169617
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6fab5f']
# Claim:
#  in education we are the worst of brazil
# Rating:
#  exagerado
#
# Predicted: 0.9131413698196411
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d7002d3']
# Claim:
#  fbi clears michael flynn in probe linking him to russia
# Rating:
#  false
#
# Predicted: 0.9599058032035828
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d70294c']
# Claim:
#  muslim nurses now have the option of participating in medical operations without washing their hands
# Rating:
#  false
#
# Predicted: 0.9999791383743286
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d700e65']
# Claim:
#  says donald trump wants to carpet bomb the enemy in the middle east
# Rating:
#  false
#
# Predicted: 0.9599058032035828
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6fbcab']
# Claim:
#  muslim nurses now have the option of participating in medical operations without washing their hands
# Rating:
#  false
#
# Predicted: 0.9887133836746216
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6ff600']
# Claim:
#  nobody on medicaid will have their benefits taken away
# Rating:
#  false
#
# Predicted: 0.9809196591377258
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d7037a8']
# Claim:
#  not giving 5 billion for joesley buy companies in the united states or argentina or giving to buy gerdau steel in colombia we will help this country
# Rating:
#  subestimado
#
# Predicted: 0.9951146841049194
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d7008a2']
# Claim:
#  later this year the federal government intended to withdraw 90 million this work duplication of the br 381 i am going out of the budget it was just the mining bench in the house and senate to stop we mobilize we stopped the vote on the budget review and we keep this value
# Rating:
#  exagerado
#
# Predicted: 0.9131413698196411
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6f97b1']
# Claim:
#  fbi clears michael flynn in probe linking him to russia
# Rating:
#  false
#
# Predicted: 0.9734939336776733
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d701ae6']
# Claim:
#  today there are more than 7 million americans more living in poverty than the day that barack obama became president of the united states
# Rating:
#  false
#
# Predicted: 0.9942367076873779
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6f9709']
# Claim:
#  this video of a disabled toddler trying to shake trump s hand and getting ignored will break your heart
# Rating:
#  false
#
# Predicted: 0.9942367076873779
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d700a23']
# Claim:
#  this video of a disabled toddler trying to shake trump s hand and getting ignored will break your heart
# Rating:
#  false
#
# Predicted: 0.9990453124046326
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6fc81a']
# Claim:
#  mccain accidentally killed 134 u s soldiers while serving in navy
# Rating:
#  false
#
# Predicted: 0.9678718447685242
# Actual: 0.0
# ID: ['8907eae5-7ef2-4c1a-7507-16da7d6fe399']
# Claim:
#  you catch a criminal and you have to release him referring to people caught trying to enter the u s illegally
# Rating:
#  false

# %% [markdown]
# ---

# %% [markdown]
# # Use model to predict unknown reviews

# %%
from asterixdb.asterixdb import AsterixConnection
import json

con = AsterixConnection(server='http://localhost', port=19002)

# %% [markdown]
# Gather all pre-rated reviews:

# %%
with open('../data/partition.pickle', 'rb') as f:
    partition = pickle.load(f)

partition['rated'] = dict()
for k in partition.keys():
    if k != 'predict':
        partition['rated'].update(partition[k])
len(partition['rated'])
# Out:
# 25477

# %% [markdown]
# Create generator for unrated reviews to be predicted:

# %%
gen_unrated = DataGenerator(partition,
                           mode='predict',
                           all_text=True,
                           train_oov=False,
                           batch_size=1,
                           return_id=True)
len(gen_unrated)
# Out:
# 34597

# %% [markdown]
# Helper function to predict item in generator using model, and format into json-friendly dict:

# %%
def predict(model, generator, item):    
    text = generator.__getitem__(item)[1][0]
    score = model.predict(text)[0][0]
    isFake = bool(round(score))

    output = dict()
    output["isFake"] = isFake
    output["score"] = float(score)
    
    return output

# %% [markdown]
# Gather all reviews with boolean isFake variable, whether rated or unrated:

# %%
reviews = []

# %%
partition['rated']
# Out:
# {'8907eae5-7ef2-4c1a-7507-16da7d6f68a0': {'claim': array([   28,     8,  4816,  1758,     6,     1,  3260,    66,   215,
#             32,  6072,  1568,   220,     5, 10395,  8775,    79,    39,
#            257,     4,   458,   176,  1985,     6,     1,  3221,   106,
#             24,  1293,     9,   947,     1,   228,  2133,     4,  2694,
#            176,   172,     6,   176,   285,    39,   130,  3251,     5,
#            166,   112, 13014,    18,   656,   106,    24,  1293,    94,
#              2,   311,     3,  1089,  4127,   105,    41,    19,   111,
#            277,    41,    19,   111,   106,    24,  9741]),
#   'claim_inv': array([   28,     8,  4816,  1758,     6,     1,  3260,    66,   215,
#             32,  6072,  1568,   220,     5, 10395,  8775,    79,    39,
#            257,     4,   458,   176,  1985,     6,     1,  3221,   106,
#             24,  1293,     9,   947,     1,   228,  2133,     4,  2694,
#            176,   172,     6,   176,   285,    39,   130,  3251,     5,
#            166,   112, 13014,    18,   656,   106,    24,  1293,    94,
#              2,   311,     3,  1089,  4127,   105,    41,    19,   111,
#            277,    41,    19,   111,   106,    24,  9741]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([111, 122]),
#   'rating_inv': array([111]),
#   'rating_oov': array([122])},
#  '8907eae5-7ef2-4c1a-7507-16da7d702dc9': {'claim': array([    1,   124,   171,  5774,  2626, 15039,     1,  1980,     2,
#              1,   111,  2133,     2,    53,     1,   540,   720,   785,
#           1644,     6, 15040,    17,    15, 11670,   609,     4,  2847,
#            440,     6,   171, 15041,     6,     4,   241,   119,  3245,
#             18,  1296,  2686,     6,  5041]),
#   'claim_inv': array([    1,   124,   171,  5774,  2626, 15039,     1,  1980,     2,
#              1,   111,  2133,     2,    53,     1,   540,   720,   785,
#           1644,     6, 15040,    17,    15, 11670,   609,     4,  2847,
#            440,     6,   171, 15041,     6,     4,   241,   119,  3245,
#             18,  1296,  2686,     6,  5041]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([  37, 2479, 3238, 3239]),
#   'rating_inv': array([  37, 2479, 3238, 3239]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f5bcf': {'claim': array([   47,     1,  9199,   388,  3159,    65,   460,    88,     2,
#              1,    99,    24,   513,  1525,     6,    22,     1,  3053,
#              4,  3542,  3320, 17692,     6,  6102,   180,   197,   230,
#              6,   255,    11,     1,  2577,    79,    39,   891,     4]),
#   'claim_inv': array([   47,     1,  9199,   388,  3159,    65,   460,    88,     2,
#              1,    99,    24,   513,  1525,     6,    22,     1,  3053,
#              4,  3542,  3320, 17692,     6,  6102,   180,   197,   230,
#              6,   255,    11,     1,  2577,    79,    39,   891,     4]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([102,  11,  83]),
#   'rating_inv': array([102,  11,  83]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fbc57': {'claim': array([ 184, 2824,   36,    3, 2983,   19, 4480,    9,  358,  281, 2108,
#             1, 5281]),
#   'claim_inv': array([ 184, 2824,   36,    3, 2983,   19, 4480,    9,  358,  281, 2108,
#             1, 5281]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([1379,  446]),
#   'rating_inv': array([1379,  446]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6feaf1': {'claim': array([ 1149,    40,     2,    53,   365, 10621,    51,    47,    51,
#             33,    19,     4,  2674,   762,     1,   260,   124,   118,
#              6,   785,  3951,     3,     1,  1034,    39,   208,    12,
#           1314,   154]),
#   'claim_inv': array([ 1149,    40,     2,    53,   365, 10621,    51,    47,    51,
#             33,    19,     4,  2674,   762,     1,   260,   124,   118,
#              6,   785,  3951,     3,     1,  1034,    39,   208,    12,
#           1314,   154]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([21]),
#   'rating_inv': array([21]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff174': {'claim': array([    3,   148,    17,   318,     4,   828,   187, 21300,  5735,
#              3,   927,     6,  2675,   284,     6, 21301]),
#   'claim_inv': array([    3,   148,    17,   318,     4,   828,   187, 21300,  5735,
#              3,   927,     6,  2675,   284,     6]),
#   'claim_oov': array([21301]),
#   'isFake': True,
#   'rating': array([2955]),
#   'rating_inv': array([0]),
#   'rating_oov': array([2955])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f69dd': {'claim': array([  16,  397, 1056,   69,  164]),
#   'claim_inv': array([  16,  397, 1056,   69,  164]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([2019, 2053]),
#   'rating_inv': array([2019, 2053]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff6f6': {'claim': array([497, 348,  22,  34,  35, 887, 253, 304,   3, 489, 242, 261, 119]),
#   'claim_inv': array([497, 348,  22,  34,  35, 887, 253, 304,   3, 489, 242, 261, 119]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([92]),
#   'rating_inv': array([0]),
#   'rating_oov': array([92])},
#  '8907eae5-7ef2-4c1a-7507-16da7d703941': {'claim': array([ 4535,    13,     1,    75,     9,   132,  7534, 22148,   826]),
#   'claim_inv': array([   13,     1,    75,     9,   132,  7534, 22148,   826]),
#   'claim_oov': array([4535]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7016a6': {'claim': array([    1,   104,   708, 14840,   280,   170,   781,     3,   456,
#           8183,     3,   344]),
#   'claim_inv': array([    1,   104,   708, 14840,   280,   170,   781,     3,   456,
#           8183,     3,   344]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f586e': {'claim': array([6986, 9501,  264,   16, 1469,  817,   90,  321,    6,  385,   90,
#           599,    3,    1,  323,    2,   60,   77,   52]),
#   'claim_inv': array([6986,  264,   16, 1469,  817,   90,  321,    6,  385,   90,  599,
#             3,    1,  323,    2,   60,   77,   52]),
#   'claim_oov': array([9501]),
#   'isFake': True,
#   'rating': array([    1,   385,  2722,   496,   135,  2550,  3590, 18727,     3,
#              1,   964, 12285,    44,  5422,     5, 16471,   191,     2,
#           3591,    88]),
#   'rating_inv': array([    1,   385,  2722,   496,   135,  2550,  3590, 18727,     3,
#              1,   964, 12285,    44,  5422,     5, 16471,   191,     2,
#           3591,    88]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe6e8': {'claim': array([1102, 1486,   72,    2,    5,  955,    3,  575,  361,    3, 1210]),
#   'claim_inv': array([1102, 1486,   72,    2,    5,  955,    3,  575,  361,    3, 1210]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([347]),
#   'rating_inv': array([0]),
#   'rating_oov': array([347])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fee45': {'claim': array([22256, 22257,  5085,    70,   110,   913,    54,   758,  1571,
#             10,  3725,  4294,   720,    18,  4711, 22258,  5326]),
#   'claim_inv': array([ 5085,    70,   110,   913,    54,   758,  1571,    10,  3725,
#           4294,   720,    18,  4711, 22258,  5326]),
#   'claim_oov': array([22256, 22257]),
#   'isFake': False,
#   'rating': array([1542,   14]),
#   'rating_inv': array([1542,   14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d701643': {'claim': array([  1, 317, 127, 141,   8, 326, 110, 657]),
#   'claim_inv': array([  1, 317, 127, 141,   8, 326, 110, 657]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fb5b5': {'claim': array([  17,   15, 1739,    4, 4264,    1,  935, 4286,    4, 1180, 5348]),
#   'claim_inv': array([  17,   15, 1739,    4, 4264,    1,  935, 4286,    4, 1180]),
#   'claim_oov': array([5348]),
#   'isFake': True,
#   'rating': array([10863, 10864]),
#   'rating_inv': array([10863, 10864]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d70382f': {'claim': array([  129,     3,  1079, 10588,     1,  3053,     4,   188,   688,
#             35,   349,     3,  2144,     2,     1,   513,   327,     2,
#              1,   736,   378,  2118,     3,   199,     8,   357,    35,
#              1,   378,   472,   379, 22706]),
#   'claim_inv': array([  129,     3,  1079, 10588,     1,  3053,     4,   188,   688,
#             35,   349,     3,  2144,     2,     1,   513,   327,     2,
#              1,   736,   378,  2118,     3,   199,     8,   357,    35,
#              1,   378,   472,   379]),
#   'claim_oov': array([22706]),
#   'isFake': True,
#   'rating': array([881, 882]),
#   'rating_inv': array([881, 882]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fdff2': {'claim': array([   12,     5,   464,  5822,  1630,  5048,    13, 14131,   186,
#           1058,     6,   344]),
#   'claim_inv': array([   12,     5,   464,  5822,  1630,  5048,    13, 14131,   186,
#           1058,     6,   344]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff10b': {'claim': array([ 685,  321, 3577,    3,    1, 4357,    8, 6044,    6, 1793,  111,
#          1221,  271]),
#   'claim_inv': array([ 685,  321, 3577,    3,    1, 4357,    8, 6044,    6, 1793,  111,
#          1221,  271]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([573]),
#   'rating_inv': array([0]),
#   'rating_oov': array([573])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7268': {'claim': array([  69,  508, 4521, 3541,   27,   42,    2,    1, 1134,  558, 3373,
#           114,    3,    1,  715]),
#   'claim_inv': array([  69,  508, 4521, 3541,   27,   42,    2,    1, 1134,  558, 3373,
#           114,    3,    1,  715]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fb9ac': {'claim': array([   1, 3120,    2, 2558,   19,   61,  245,   23,    1, 1017,  287,
#             4,  940]),
#   'claim_inv': array([   1, 3120,    2, 2558,   19,   61,  245,   23,    1, 1017,  287,
#             4,  940]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d70041c': {'claim': array([   70, 21724,    24,   216,   263,  3495,  6203,    22,  3969,
#             18,    64,   189,   936]),
#   'claim_inv': array([  70,   24,  216,  263, 3495,   22, 3969,   18,   64,  189,  936]),
#   'claim_oov': array([21724,  6203]),
#   'isFake': True,
#   'rating': array([31,  7]),
#   'rating_inv': array([31,  7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7023cc': {'claim': array([14974,    94,     2,   180, 15196,   614,    20,    53,   726,
#              4,  1815,     2,   785,  3422]),
#   'claim_inv': array([14974,    94,     2,   180, 15196,   614,    20,    53,   726,
#              4,  1815,     2,   785,  3422]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([367]),
#   'rating_inv': array([367]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff4b3': {'claim': array([14606, 14607,     1,  7000,   124,    44,    13,   374,     3,
#              5,   603,   305,     3,    69,   508,   150,   104,    48,
#           1265,     5,   704,     2,    36,    18,   320,    39,   177,
#            879,    36]),
#   'claim_inv': array([   1, 7000,  124,   44,   13,  374,    3,    5,  603,  305,    3,
#            69,  508,  150,  104,   48, 1265,    5,  704,    2,   36,   18,
#           320,   39,  177,  879,   36]),
#   'claim_oov': array([14606, 14607]),
#   'isFake': True,
#   'rating': array([2193]),
#   'rating_inv': array([2193]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fbf3b': {'claim': array([  405,    30,     1,   164,   542,     9,    50,   130,   687,
#            104,   783,   277,  1821,     8, 21261,   313]),
#   'claim_inv': array([  405,    30,     1,   164,   542,     9,    50,   130,   687,
#            104,   783,   277,  1821,     8, 21261,   313]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([1270,    1,  390]),
#   'rating_inv': array([1270,    1,  390]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d701a33': {'claim': array([1921,  719,  665,  135, 5430, 2672,   68,  589,  228, 1072, 6030,
#          3686]),
#   'claim_inv': array([1921,  719,  665,  135, 5430, 2672,   68,  589,  228, 1072, 6030,
#          3686]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f800d': {'claim': array([   17,  5094,     9,    18,     1,  2858,    90,     3,     1,
#             96,    48,    38,    33,    29,   222,  1474,     4,     1,
#          13674,   244,    56,   303,    82,    59,    17,    15,   248,
#              4,  3972,   186,  3384,     6,  2604,    82,   276,    17,
#           7764,     9,    33,  1274,    30,   522,   303,    82,    34,
#              3,   335,  3593,    23,   607, 14053,     6,   607, 23563]),
#   'claim_inv': array([   17,  5094,     9,    18,     1,  2858,    90,     3,     1,
#             96,    48,    38,    33,    29,   222,  1474,     4,     1,
#          13674,   244,    56,   303,    82,    59,    17,    15,   248,
#              4,  3972,   186,  3384,     6,  2604,    82,   276,    17,
#           7764,     9,    33,  1274,    30,   522,   303,    82,    34,
#              3,   335,  3593,    23,   607, 14053,     6,   607, 23563]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([21]),
#   'rating_inv': array([21]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fd949': {'claim': array([   5,  233,  178, 7613, 3215, 1754,    1, 1118,    1,  869,  771]),
#   'claim_inv': array([   5,  233,  178, 7613, 3215, 1754,    1, 1118,    1,  869,  771]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([1151,  992, 1152]),
#   'rating_inv': array([1151,  992, 1152]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7024c5': {'claim': array([21115,     8,     1,   132,  1011,   150,     3,  2981,  3805,
#          14356,     3,     1, 21116, 21117,   798,    16,     8,     1,
#            150,     9,  1272,   536,  1111,     2,   562,     3,     1,
#             75]),
#   'claim_inv': array([    8,     1,   132,  1011,   150,     3,  2981,  3805,     3,
#              1, 21116,   798,    16,     8,     1,   150,     9,  1272,
#            536,  1111,     2,   562,     3,     1,    75]),
#   'claim_oov': array([21115, 14356, 21117]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d702a96': {'claim': array([3202,   82,    3, 2954,   16,   24,  447,   54,  164,  192,  164,
#           907,   24,  138,  311]),
#   'claim_inv': array([3202,   82,    3, 2954,   16,   24,  447,   54,  164,  192,  164,
#           907,   24,  138,  311]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([113, 122]),
#   'rating_inv': array([113]),
#   'rating_oov': array([122])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fa9fe': {'claim': array([ 792,  118, 2205,   50,  973,    3,  354,  528]),
#   'claim_inv': array([ 792,  118, 2205,   50,  973,    3,  354,  528]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([149]),
#   'rating_inv': array([149]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d702ee6': {'claim': array([   25,   751,    18,     5,    70,    49,  2326,   458,    59,
#             25,   666,     5, 23307,   443]),
#   'claim_inv': array([   25,   751,    18,     5,    70,    49,  2326,   458,    59,
#             25,   666,     5, 23307,   443]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([113, 122]),
#   'rating_inv': array([113]),
#   'rating_oov': array([122])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fee76': {'claim': array([1024, 1235, 4058, 2055, 1804,    9,  837,  507]),
#   'claim_inv': array([1024, 1235, 4058, 2055, 1804,    9,  837,  507]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([21]),
#   'rating_inv': array([21]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7fd9': {'claim': array([  25,  339,    1,  117,   17,   19,    1,  132, 1423,   11,  131,
#           253, 1025,   23,    1,  189,    2,    1, 2063,  877,   85,    4,
#            70,  262,    2,  377,  232,    1,  239,  235,    8,  866,  247]),
#   'claim_inv': array([  25,  339,    1,  117,   17,   19,    1,  132, 1423,   11,  131,
#           253, 1025,   23,    1,  189,    2,    1, 2063,  877,   85,    4,
#            70,  262,    2,  377,  232,    1,  239,  235,    8,  866,  247]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([863]),
#   'rating_inv': array([0]),
#   'rating_oov': array([863])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f8efa': {'claim': array([   25,    19,   650,   719,     2,    75, 20902,     4,  7391,
#            770,     1,   354,   528,   826,     6,  2110, 10317,     6,
#          20903,     6,     1,   554,  2446,  1456,     2,  1094,   354,
#            749,    53,     8,    97, 14258,   826,    23,   237,  1094,
#          20904, 11272]),
#   'claim_inv': array([   25,    19,   650,   719,     2,    75,     4,  7391,   770,
#              1,   354,   528,   826,     6,  2110, 10317,     6, 20903,
#              6,     1,   554,  2446,  1456,     2,  1094,   354,   749,
#             53,     8,    97, 14258,   826,    23,   237,  1094, 11272]),
#   'claim_oov': array([20902, 20904]),
#   'isFake': True,
#   'rating': array([113, 122]),
#   'rating_inv': array([113]),
#   'rating_oov': array([122])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f8931': {'claim': array([14468,  1095, 12595,    47,  8555,     8,  4628,     1,   465,
#             40,     2,     1,    40,     2,    57,   205,   402,    51,
#              8,    12,  7508, 23060]),
#   'claim_inv': array([ 1095, 12595,    47,     8,  4628,     1,   465,    40,     2,
#              1,    40,     2,    57,   205,   402,    51,     8,    12,
#           7508]),
#   'claim_oov': array([14468,  8555, 23060]),
#   'isFake': False,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d700be6': {'claim': array([ 1454,  1100,  2487, 10709,  8979, 31240,     5,  2409,     2,
#           2360,  1420,    44,     8,   179]),
#   'claim_inv': array([ 1454,  1100,  2487, 10709, 31240,     5,  2409,     2,  2360,
#           1420,    44,     8,   179]),
#   'claim_oov': array([8979]),
#   'isFake': True,
#   'rating': array([63, 14]),
#   'rating_inv': array([63, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fd134': {'claim': array([7075,  686,   55,   79,  420,  212, 3218,   25,   33, 2744, 1133]),
#   'claim_inv': array([7075,  686,   55,   79,  420,  212, 3218,   25,   33, 2744, 1133]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d703e62': {'claim': array([  25,  444,  892,    8, 5106,   59,   41,  181,   93,   17,  294,
#           993,   10,  460,    2,  892,  604,  252,   29,  357]),
#   'claim_inv': array([  25,  444,  892,    8, 5106,   59,   41,  181,   93,   17,  294,
#           993,   10,  460,    2,  892,  604,  252,   29,  357]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([908,   1, 390]),
#   'rating_inv': array([908,   1, 390]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7034a7': {'claim': array([   3,    1, 4642, 3973,    3,   60,   75,  512,   13,   37,   70,
#             3, 1011,  301,    3,  278,    1,   71, 4006,   25,   73,   13,
#            10,    1,  379,    2,  512,   44,   50, 6415,    4,    5, 1011,
#           301,  180,  111, 1344,    6, 1246, 5215]),
#   'claim_inv': array([   3,    1, 4642, 3973,    3,   60,   75,  512,   13,   37,   70,
#             3, 1011,  301,    3,  278,    1,   71, 4006,   25,   73,   13,
#            10,    1,  379,    2,  512,   44,   50, 6415,    4,    5, 1011,
#           301,  180,  111, 1344,    6, 1246, 5215]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe900': {'claim': array([  330,   463,  1301, 10231,  6638,  4416,     3,   110,    45]),
#   'claim_inv': array([  330,   463,  1301, 10231,  6638,  4416,     3,   110,    45]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d703da0': {'claim': array([  38,   15,  207, 4631,   82,    9,  554,  410,   15,    4,  171,
#           223]),
#   'claim_inv': array([  38,   15,  207, 4631,   82,    9,  554,  410,   15,    4,  171,
#           223]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([92]),
#   'rating_inv': array([0]),
#   'rating_oov': array([92])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f5f01': {'claim': array([   3,  964, 6175,   60,  387, 2871,   13, 1197,   45,    6,   97,
#            16,   24,  289, 3591]),
#   'claim_inv': array([   3,  964, 6175,   60,  387, 2871,   13, 1197,   45,    6,   97,
#            16,   24,  289, 3591]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([1540,   14]),
#   'rating_inv': array([1540,   14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7033c6': {'claim': array([ 1215,    20, 22428, 11624,     4,  3465,    85,   184,   477,
#           8514,    10,     1,   388,  1391,    18,  8872]),
#   'claim_inv': array([ 1215,    20, 22428, 11624,     4,  3465,    85,   184,   477,
#           8514,    10,     1,   388,  1391,    18,  8872]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([31,  7]),
#   'rating_inv': array([31,  7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7031a7': {'claim': array([    1,  2253,     2,     1,   401,  1835,    10,   833,     8,
#            133,   309,  1639,     3,   661,     6,  2027,    18,     1,
#           1392,   117,     2,   603,   794,    16,    33,   234,  1707,
#             18,     1, 10316,     6,  3976,   329,  4051]),
#   'claim_inv': array([    1,  2253,     2,     1,   401,  1835,    10,   833,     8,
#            133,   309,  1639,     3,   661,     6,  2027,    18,     1,
#           1392,   117,     2,   603,   794,    16,    33,   234,  1707,
#             18,     1, 10316,     6,  3976,   329,  4051]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff1a7': {'claim': array([   28, 21600,    69,   727,    33,  7038,    60,  5029,     6,
#           3933,   379,     4,   444, 11446,     6,     4,  1010,     5,
#            554,  2837,   229,    28,    66,   389,  1268,   261,     2,
#           5685,    17,   375,     4,    29, 12452,     4,   880,    60,
#            473, 12661,  1864,     6,  4381,    60,  1563,  1324, 11310,
#              1,  2162,     4,   133,   621,     4,    76,     9,  3844,
#             18,     1,   916,    10,  1276,     2,   658]),
#   'claim_inv': array([   28, 21600,    69,   727,    33,  7038,    60,  5029,     6,
#           3933,   379,     4,   444, 11446,     6,     4,  1010,     5,
#            554,  2837,   229,    28,    66,   389,  1268,   261,     2,
#           5685,    17,   375,     4,    29, 12452,     4,   880,    60,
#            473, 12661,  1864,     6,  4381,    60,  1563,  1324, 11310,
#              1,  2162,     4,   133,   621,     4,    76,     9,  3844,
#             18,     1,   916,    10,  1276,     2,   658]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([109]),
#   'rating_inv': array([109]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fd8cc': {'claim': array([ 8949,  9661,  1596,     3,     5, 12438,     4,     1,  4351,
#           2110]),
#   'claim_inv': array([ 8949,  9661,  1596,     3,     5, 12438,     4,     1,  4351,
#           2110]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe833': {'claim': array([    5,  2145,  1173,   786,  3204,     5,  1528,    18,    40,
#            829,    24, 12416]),
#   'claim_inv': array([    5,  2145,  1173,   786,  3204,     5,  1528,    18,    40,
#            829,    24, 12416]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe655': {'claim': array([ 4835,    38,     8,   143,  1116,    56,   532,   757, 21485]),
#   'claim_inv': array([4835,   38,    8,  143, 1116,   56,  532,  757]),
#   'claim_oov': array([21485]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fda8e': {'claim': array([30641,  5543,  5560,  1768,    98,    86,  1469,  2055,  1486,
#              2, 17300, 17301, 22870,    85,  1041,   451,    52]),
#   'claim_inv': array([30641,  5543,  5560,  1768,    98,    86,  1469,  2055,  1486,
#              2, 17300, 17301, 22870,    85,  1041,   451,    52]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7023c0': {'claim': array([   40,     2,  4224, 11896, 11897, 15481,     3, 31280]),
#   'claim_inv': array([   40,     2,  4224, 11897,     3, 31280]),
#   'claim_oov': array([11896, 15481]),
#   'isFake': True,
#   'rating': array([21]),
#   'rating_inv': array([21]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7036cf': {'claim': array([ 1024,    11,  1984,   133,    32, 31717,   400,     2,   353,
#           7736,     4, 17806, 31718]),
#   'claim_inv': array([ 1024,    11,  1984,   133,    32, 31717,   400,     2,   353,
#           7736,     4, 17806, 31718]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fba01': {'claim': array([  429,   874,  1208,   563,     6,  1196, 10736, 24378,  1813]),
#   'claim_inv': array([  429,   874,  1208,   563,     6,  1196, 10736,  1813]),
#   'claim_oov': array([24378]),
#   'isFake': False,
#   'rating': array([1542,   14]),
#   'rating_inv': array([1542,   14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe331': {'claim': array([ 8241,  2827,  1257, 14549,     2,  2110,  7381,  1440,   845,
#           3001, 21463,   758,  1571, 14550,     3,    42,   386, 14551]),
#   'claim_inv': array([ 8241,  2827,  1257, 14549,     2,  2110,  7381,  1440,   845,
#           3001, 21463,   758,  1571, 14550,     3,    42,   386, 14551]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe590': {'claim': array([ 382, 1798,  177,   28,    8,   32, 2195, 2078,   20,   40,   43,
#            25,   66,   76,  176,  655,  267,  143, 1294, 4904]),
#   'claim_inv': array([ 382, 1798,  177,   28,    8,   32, 2195, 2078,   20,   40,   43,
#            25,   66,   76,  176,  655,  267,  143, 1294, 4904]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff6f2': {'claim': array([ 339,  313, 1891,   93,   19,   41,  341,  200, 2646,   38,   15,
#            37,  365, 2672,    6,   38,  183,   33,   29]),
#   'claim_inv': array([ 339,  313, 1891,   93,   19,   41,  341,  200, 2646,   38,   15,
#            37,  365, 2672,    6,   38,  183,   33,   29]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d700d00': {'claim': array([22587,   170,  3672,  1666,     8,    12,  2196,     1, 11655,
#           2001,  4904]),
#   'claim_inv': array([22587,   170,  3672,  1666,     8,    12,  2196,     1, 11655,
#           2001,  4904]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([31,  7]),
#   'rating_inv': array([31,  7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fd2bb': {'claim': array([  298, 15419,    23,  2994,     3, 12355]),
#   'claim_inv': array([  298, 15419,    23,  2994,     3, 12355]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fa1a2': {'claim': array([6951, 6111,   22,  106, 1193,   11,  140, 1482,    4, 2114,  332,
#           709,  317]),
#   'claim_inv': array([6951, 6111,   22,  106, 1193,   11,  140, 1482,    4, 2114,  332,
#           709,  317]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([5613]),
#   'rating_inv': array([5613]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d700443': {'claim': array([    1,  2183,   337,     3,   329,   790,     8,  1807,     3,
#            159,   187,    70,  3311,    20,     5, 15271,    85,     4,
#             70,   137,    70,   110,     3,   361,  1128,    45]),
#   'claim_inv': array([    1,  2183,   337,     3,   329,   790,     8,  1807,     3,
#            159,   187,    70,  3311,    20,     5, 15271,    85,     4,
#             70,   137,    70,   110,     3,   361,  1128,    45]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([1388, 1389]),
#   'rating_inv': array([1388, 1389]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff17b': {'claim': array([21302, 21303,    49,   243,    11,  5009,    20,     1,   869,
#             11,   366,   407]),
#   'claim_inv': array([21302, 21303,    49,   243,    11,  5009,    20,     1,   869,
#             11,   366,   407]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([109]),
#   'rating_inv': array([109]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fcec6': {'claim': array([ 336,    8,  248,    4,   19, 1083,    1,  117,    2, 8484,   17,
#            19,    3,  130,   74,    5, 1411]),
#   'claim_inv': array([ 336,    8,  248,    4,   19, 1083,    1,  117,    2, 8484,   17,
#            19,    3,  130,   74,    5, 1411]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([63, 14]),
#   'rating_inv': array([63, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fdd2d': {'claim': array([  176,  2144,  1789,     9,     8,    38,     8,   169, 30669]),
#   'claim_inv': array([  176,  2144,  1789,     9,     8,    38,     8,   169, 30669]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d702c11': {'claim': array([ 7310, 22545,  1199,   898,     9,   270,    81,    19,     4,
#           1161,   685,  1017,   622]),
#   'claim_inv': array([7310, 1199,  898,    9,  270,   81,   19,    4, 1161,  685, 1017,
#           622]),
#   'claim_oov': array([22545]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d702ee8': {'claim': array([ 700,    4,   63,    2,    1,  722,    3,  278,    1,   71,   90,
#            39,  204,    8,    1, 4130,   90]),
#   'claim_inv': array([ 700,    4,   63,    2,    1,  722,    3,  278,    1,   71,   90,
#            39,  204,    8,    1, 4130,   90]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([63, 14]),
#   'rating_inv': array([63, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fbbac': {'claim': array([ 624, 3701,  210,  693,   36,    6, 1939, 9529,   23,    1,  117,
#            57,    2,    1,   36,    9,   73,  477,  121,  218,    9,   39,
#          7127,    9,   13,  406,  483,   23,  155]),
#   'claim_inv': array([ 624, 3701,  210,  693,   36,    6, 1939, 9529,   23,    1,  117,
#            57,    2,    1,   36,    9,   73,  477,  121,  218,    9,   39,
#          7127,    9,   13,  406,  483,   23,  155]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([113, 122]),
#   'rating_inv': array([113]),
#   'rating_oov': array([122])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fa847': {'claim': array([ 490,   38,   29,   37, 3426,   79,    1,  198,    8,  523,  442,
#             2,  213, 2588,  398, 1011, 5112,    6,  637, 2588,   33,   29,
#           687, 2076,   35,   39,   87,   29,  135,  577,  125]),
#   'claim_inv': array([ 490,   38,   29,   37, 3426,   79,    1,  198,    8,  523,  442,
#             2,  213, 2588,  398, 1011, 5112,    6,  637, 2588,   33,   29,
#           687, 2076,   35,   39,   87,   29,  135,  577,  125]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([ 84, 122]),
#   'rating_inv': array([84]),
#   'rating_oov': array([122])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f5b7b': {'claim': array([ 684, 3825, 8980, 5721,    4,    1, 4560,   10, 2536,    2, 2237]),
#   'claim_inv': array([ 684, 3825, 8980, 5721,    4,    1, 4560,   10, 2536,    2, 2237]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fd108': {'claim': array([ 193,  265,   10,   12, 1925, 4028,  330]),
#   'claim_inv': array([ 193,  265,   10,   12, 1925, 4028,  330]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe3b5': {'claim': array([  363,  2239,  2790,    13,  1302,  1083,    10,   804,     6,
#           7474, 11419]),
#   'claim_inv': array([  363,  2239,  2790,    13,  1302,  1083,    10,   804,     6,
#           7474, 11419]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([21]),
#   'rating_inv': array([21]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f6e9d': {'claim': array([3051, 3341,  120,  873,    3,  950,   15, 9414,    6,  570,  688]),
#   'claim_inv': array([3051, 3341,  120,  873,    3,  950,   15, 9414,    6,  570,  688]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([2019, 2053]),
#   'rating_inv': array([2019, 2053]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d703599': {'claim': array([1695, 3133, 1386,   25,  257,    4,   96, 2320,  184,    2,    1,
#          1386,   33,   12,   29, 1852,    6,    1, 1313, 2648,    4,  114,
#           302,    1, 6735, 1512,  398,    1, 2227,  809,   10, 2919, 4130,
#             6, 2683, 2291]),
#   'claim_inv': array([1695, 3133, 1386,   25,  257,    4,   96, 2320,  184,    2,    1,
#          1386,   33,   12,   29, 1852,    6,    1, 1313, 2648,    4,  114,
#           302,    1, 6735, 1512,  398,    1, 2227,  809,   10, 2919, 4130,
#             6, 2683, 2291]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([146]),
#   'rating_inv': array([146]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f9677': {'claim': array([  135,  4221,  9541,   322,  1227,    22,   998,     4, 11287,
#              3,  1026,   204]),
#   'claim_inv': array([  135,  4221,   322,  1227,    22,   998,     4, 11287,     3,
#           1026,   204]),
#   'claim_oov': array([9541]),
#   'isFake': True,
#   'rating': array([31,  7]),
#   'rating_inv': array([31,  7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fb70a': {'claim': array([  17,  527,    2,  976,   12,   71,    4,  828,   34,   16,    8,
#           926,    4,  893,   85,    1, 2033,   28,  796,    9,   30,  522,
#             5, 1734,  191,  321,    8, 2150,    4, 3315, 2726, 1708]),
#   'claim_inv': array([  17,  527,    2,  976,   12,   71,    4,  828,   34,   16,    8,
#           926,    4,  893,   85,    1, 2033,   28,  796,    9,   30,  522,
#             5, 1734,  191,  321,    8, 2150,    4, 3315, 2726, 1708]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([2480]),
#   'rating_inv': array([0]),
#   'rating_oov': array([2480])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7f7b': {'claim': array([  786, 21622,  2697,  2265,  3272,  1252,   101,     1,   836,
#            686,   545,   152,   248,    30,    16,    18,    40,   107,
#            276,   265,   101,    16,    97,    51,    47,    25,   208,
#             12,    19,  7488,     1,   545]),
#   'claim_inv': array([  786, 21622,  2697,  2265,  3272,  1252,   101,     1,   836,
#            686,   545,   152,   248,    30,    16,    18,    40,   107,
#            276,   265,   101,    16,    97,    51,    47,    25,   208,
#             12,    19,  7488,     1,   545]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff779': {'claim': array([2784, 2284,   47, 1682, 2085, 2110,    6, 2159,   10,  533,    3,
#          4661]),
#   'claim_inv': array([2784, 2284,   47, 1682, 2085, 2110,    6, 2159,   10,  533,    3,
#          4661]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7000e8': {'claim': array([   84,  5033,   374,    10,  2006,   831,     3, 21701,   243,
#              3,   844]),
#   'claim_inv': array([   84,  5033,   374,    10,  2006,   831,     3, 21701,   243,
#              3,   844]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([123, 147]),
#   'rating_inv': array([123, 147]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7e1a': {'claim': array([ 1469,   533,  5578,   499, 24245,   537,  1722,    18,  2616,
#           6290,  1655,    86,    39,    76,    12,   236,    16,    52]),
#   'claim_inv': array([ 1469,   533,   499, 24245,   537,  1722,    18,  2616,  6290,
#           1655,    86,    39,    76,    12,   236,    16,    52]),
#   'claim_oov': array([5578]),
#   'isFake': True,
#   'rating': array([1869, 1870]),
#   'rating_inv': array([1869, 1870]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fc495': {'claim': array([4483,    3, 1054, 2065,  257,   60, 1335,    4,   29,    5, 2010,
#          1054]),
#   'claim_inv': array([4483,    3, 1054, 2065,  257,   60, 1335,    4,   29,    5, 2010,
#          1054]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([102,  11,  83]),
#   'rating_inv': array([102,  11,  83]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d702bb0': {'claim': array([ 439,   15, 3423,    4,   29,  250,   11, 2441]),
#   'claim_inv': array([ 439,   15, 3423,    4,   29,  250,   11, 2441]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d701d4f': {'claim': array([ 867,   33, 3617, 4062,    9, 3565, 3478]),
#   'claim_inv': array([ 867,   33, 3617, 4062,    9, 3565, 3478]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([240]),
#   'rating_inv': array([240]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f598c': {'claim': array([  118,     8,  1292,    20,   618,  2901,     6,   401,    18,
#           1245, 11726,     3,     1,   322,     2,   506,   190,   948]),
#   'claim_inv': array([  118,     8,  1292,    20,   618,  2901,     6,   401,    18,
#           1245, 11726,     3,     1,   322,     2,   506,   190,   948]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([21]),
#   'rating_inv': array([21]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7099': {'claim': array([   78,   535,  2009,  3403,     5,   693,   299,   157,    51,
#             13,   256,   530,     5,  3740,   321,   335,    16,    13,
#           8844,     6,    13,   666,    20,    64, 13018,  1986,     1,
#           1474,     2,     1,  1921,     2,     1,   144,   114,     3,
#              5,   693,    45,   245,    20,   244,    68,   706,     1,
#            209,   918,    78,  1960,  1592,   321,     1,    34,  6758,
#              3,     1, 23514,   248,    23,     1,  2725,    90,     2,
#           2288,  2725,    90,     2,  1085,     6,   152,   311,    16,
#            934,     5,   244,   231,     3,  1474,  1329,  6452,  8913,
#             89,     1,   209]),
#   'claim_inv': array([   78,   535,  2009,  3403,     5,   693,   299,   157,    51,
#             13,   256,   530,     5,  3740,   321,   335,    16,    13,
#           8844,     6,    13,   666,    20,    64, 13018,  1986,     1,
#           1474,     2,     1,  1921,     2,     1,   144,   114,     3,
#              5,   693,    45,   245,    20,   244,    68,   706,     1,
#            209,   918,    78,  1960,  1592,   321,     1,    34,  6758,
#              3,     1,   248,    23,     1,  2725,    90,     2,  2288,
#           2725,    90,     2,  1085,     6,   152,   311,    16,   934,
#              5,   244,   231,     3,  1474,  1329,  6452,  8913,    89,
#              1,   209]),
#   'claim_oov': array([23514]),
#   'isFake': True,
#   'rating': array([876]),
#   'rating_inv': array([0]),
#   'rating_oov': array([876])},
#  '8907eae5-7ef2-4c1a-7507-16da7d703a72': {'claim': array([ 6023,   627,    61,    32, 31315,     2,  2270,  3296,     6,
#          31316,   190,  9777]),
#   'claim_inv': array([ 6023,   627,    61,    32, 31315,     2,  2270,  3296,     6,
#          31316,   190,  9777]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([21]),
#   'rating_inv': array([21]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fee46': {'claim': array([ 123, 1118,   72,   23, 5282,  612, 1239, 1634,  713,   13, 4796,
#          1649,    3, 3552, 1713]),
#   'claim_inv': array([ 123, 1118,   72,   23, 5282,  612, 1239, 1634,  713,   13, 4796,
#          1649,    3, 3552, 1713]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe39f': {'claim': array([   47,   106,    24,   791,  2464,  2465,  2182,   288,     5,
#            131,    49, 11924,    23,  5796]),
#   'claim_inv': array([   47,   106,    24,   791,  2464,  2182,   288,     5,   131,
#             49, 11924,    23,  5796]),
#   'claim_oov': array([2465]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7f07': {'claim': array([  34,   35,   84, 1851,    2,    1, 1458,    1,  107,  308,   22,
#          1265,    4,    1,  144,  114,  135,    1,  868,  192, 3428,  325,
#          3249,   81,  408, 3428,   30,   57]),
#   'claim_inv': array([  34,   35,   84, 1851,    2,    1, 1458,    1,  107,  308,   22,
#          1265,    4,    1,  144,  114,  135,    1,  868,  192, 3428,  325,
#          3249,   81,  408, 3428,   30,   57]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([31, 14]),
#   'rating_inv': array([31, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe67b': {'claim': array([ 246,  313,    4, 1729,  529,   97,   17,   19, 9098,    1,  117,
#             2,  227, 3331, 2045]),
#   'claim_inv': array([ 246,  313,    4, 1729,  529,   97,   17,   19, 9098,    1,  117,
#             2,  227, 3331, 2045]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f98ab': {'claim': array([  660, 17207,     1,  1048,   229,    39,  3705,     3, 22539,
#          22540,  1253,  1600]),
#   'claim_inv': array([  660, 17207,     1,  1048,   229,    39,  3705,     3, 22539,
#          22540,  1253,  1600]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([ 607, 2667]),
#   'rating_inv': array([607]),
#   'rating_oov': array([2667])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff432': {'claim': array([   47,   106,    24,   791,  3495, 11849,   265,     4,   505,
#           2117,     4,   204,    34,    10,  4116,   761]),
#   'claim_inv': array([  47,  106,   24,  791, 3495,  265,    4,  505, 2117,    4,  204,
#            34,   10, 4116,  761]),
#   'claim_oov': array([11849]),
#   'isFake': True,
#   'rating': array([63, 14]),
#   'rating_inv': array([63, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff35a': {'claim': array([  68,  200, 8851,   76,   12, 1672, 3861,    6,   41,  862,    1,
#           132, 1672]),
#   'claim_inv': array([  68,  200, 8851,   76,   12, 1672, 3861,    6,   41,  862,    1,
#           132, 1672]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([573]),
#   'rating_inv': array([0]),
#   'rating_oov': array([573])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe727': {'claim': array([ 38,   8,  37,  90, 231,   3,   1, 533,  24, 318]),
#   'claim_inv': array([ 38,   8,  37,  90, 231,   3,   1, 533,  24, 318]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([31,  7]),
#   'rating_inv': array([31,  7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f93af': {'claim': array([20927,     8,   837,     4,    29,     1,  3338,     2,    57,
#            213,   114,    16,    22,     1,   595,   301,     6,     1,
#            338,  5234,   191]),
#   'claim_inv': array([20927,     8,   837,     4,    29,     1,  3338,     2,    57,
#            213,   114,    16,    22,     1,   595,   301,     6,     1,
#            338,  5234,   191]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([1153, 1898]),
#   'rating_inv': array([1153, 1898]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f727e': {'claim': array([6163,   30,    1,  467,  124, 1735,  138, 1102, 7609,    2,    1,
#           711,  603, 1788, 4019,   20,  822]),
#   'claim_inv': array([6163,   30,    1,  467,  124, 1735,  138, 1102, 7609,    2,    1,
#           711,  603, 1788, 4019,   20,  822]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d70048d': {'claim': array([  69,  508,   75, 1737,   34,   35,  262,   82,    3, 1682,  169,
#           500,   48,   11,  655, 1610, 1386,   34,   35,    1, 2765,  513,
#             2,    1,  485,  111,  385,  114]),
#   'claim_inv': array([  69,  508,   75, 1737,   34,   35,  262,   82,    3, 1682,  169,
#           500,   48,   11,  655, 1610, 1386,   34,   35,    1, 2765,  513,
#             2,    1,  485,  111,  385,  114]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([63, 14]),
#   'rating_inv': array([63, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f9345': {'claim': array([    1,    69,   555,    23,     1,   213,  9543,   285,    10,
#              1,   218,   225,     1,  4057,     2,     1, 15035,     2,
#              1,   104,    53,     1, 24007,     8,  2825,  8523,     6,
#             22,  1540,  1343,   116,    70, 24008,     1,  3176,  4210,
#           2207,   397,     8, 24009]),
#   'claim_inv': array([    1,    69,   555,    23,     1,   213,  9543,   285,    10,
#              1,   218,   225,     1,  4057,     2,     1, 15035,     2,
#              1,   104,    53,     1, 24007,     8,  2825,  8523,     6,
#             22,  1540,  1343,   116,    70,     1,  3176,  4210,  2207,
#            397,     8, 24009]),
#   'claim_oov': array([24008]),
#   'isFake': False,
#   'rating': array([1153, 7212]),
#   'rating_inv': array([1153, 7212]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f9ab0': {'claim': array([ 104, 1150,   38,   50,    5,  693,  594,   78,    1,  124, 1224,
#          1233,    4, 1274,    1, 2021, 1377,   10,    1, 7938,    2,   72,
#          3780,   80,    8,  221, 3421,    4,    1, 1177,  125]),
#   'claim_inv': array([ 104, 1150,   38,   50,    5,  693,  594,   78,    1,  124, 1224,
#          1233,    4, 1274,    1, 2021, 1377,   10,    1, 7938,    2,   72,
#          3780,   80,    8,  221, 3421,    4,    1, 1177,  125]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([13490]),
#   'rating_inv': array([0]),
#   'rating_oov': array([13490])},
#  '8907eae5-7ef2-4c1a-7507-16da7d70299b': {'claim': array([1552,  224, 2724, 1273, 3016,   10,  224,   45, 2794,    2,  635,
# ...
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ffbf6': {'claim': array([  47,  166,  112,  531,    4, 1124,    3,  442,    2,  538,    4,
#           278,   23,   57,  326,    1,   99,  267,  143, 1396,    2,  223,
#          7802]),
#   'claim_inv': array([  47,  166,  112,  531,    4, 1124,    3,  442,    2,  538,    4,
#           278,   23,   57,  326,    1,   99,  267,  143, 1396,    2,  223,
#          7802]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe72b': {'claim': array([ 106,   24,  791, 8223, 6968,   13, 3337,    3, 1068,    2,    5,
#           634,    2, 4229, 2990, 3744,    6,   32,  822,  582]),
#   'claim_inv': array([ 106,   24,  791, 8223,   13, 3337,    3, 1068,    2,    5,  634,
#             2, 4229, 2990, 3744,    6,   32,  822,  582]),
#   'claim_oov': array([6968]),
#   'isFake': True,
#   'rating': array([102,  11,  83]),
#   'rating_inv': array([102,  11,  83]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f6c4c': {'claim': array([11514, 23497,     3, 15300,  2573]),
#   'claim_inv': array([11514, 23497,     3, 15300,  2573]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([123, 147]),
#   'rating_inv': array([123, 147]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f8954': {'claim': array([   1,  793,   10,    1,  144,  114,    4,  985, 2904,  298,   23,
#           686,   33, 1576, 7491,  686,   24,  553,  325]),
#   'claim_inv': array([   1,  793,   10,    1,  144,  114,    4,  985, 2904,  298,   23,
#           686,   33, 1576, 7491,  686,   24,  553,  325]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([31,  7]),
#   'rating_inv': array([31,  7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f6005': {'claim': array([  17,   19,  116,  560,  484,  436,  460,   54,   36,   44,   19,
#            61, 2390, 3210,    3, 1455]),
#   'claim_inv': array([  17,   19,  116,  560,  484,  436,  460,   54,   36,   44,   19,
#            61, 2390, 3210,    3, 1455]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([ 392, 1015]),
#   'rating_inv': array([ 392, 1015]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f5a25': {'claim': array([  775,   270,    81,  8799, 20460,     4,  1837, 14054,  1039,
#            143,    34,   116,  2493,   539,   117, 20461, 14055, 20462]),
#   'claim_inv': array([  775,   270,    81,  8799, 20460,     4,  1837, 14054,  1039,
#            143,    34,   116,  2493,   539,   117, 20461, 14055, 20462]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([1964]),
#   'rating_inv': array([1964]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d701d0a': {'claim': array([ 432,  958, 3568, 2040, 1400,   11,  137, 4763]),
#   'claim_inv': array([ 432,  958, 3568, 2040, 1400,   11,  137, 4763]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([31,  7]),
#   'rating_inv': array([31,  7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7029a6': {'claim': array([3730,   22,    4, 4844, 5547,    6, 9622, 7060]),
#   'claim_inv': array([3730,   22,    4, 4844, 5547,    6, 9622, 7060]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([240]),
#   'rating_inv': array([240]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f55cc': {'claim': array([  34,  237,   36,   19,   61,  728,   20,  118, 1028,   28,  462,
#            48,   35, 6123]),
#   'claim_inv': array([  34,  237,   36,   19,   61,  728,   20,  118, 1028,   28,  462,
#            48,   35, 6123]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([ 84, 122]),
#   'rating_inv': array([84]),
#   'rating_oov': array([122])},
#  '8907eae5-7ef2-4c1a-7507-16da7d70024e': {'claim': array([   1,  239,   22,  221, 3152,   38,   12, 8267,   27,    1, 1348,
#           117]),
#   'claim_inv': array([   1,  239,   22,  221, 3152,   38,   12, 8267,   27,    1, 1348,
#           117]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([249]),
#   'rating_inv': array([249]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7249': {'claim': array([ 478,  428,  410,    3,   28,   77,  877,  186,  316,    6,  424,
#            88,   11,  308,  590,    1,  334,    2, 8192,    1,  939,  325,
#             5,  210, 1244,  325,    9, 1018,  411,   10,   60, 2117,    8,
#            62,   88,   17,   66, 1180, 1952,  447,   82,    5,   48,  130,
#             3,  308,  590]),
#   'claim_inv': array([ 478,  428,  410,    3,   28,   77,  877,  186,  316,    6,  424,
#            88,   11,  308,  590,    1,  334,    2, 8192,    1,  939,  325,
#             5,  210, 1244,  325,    9, 1018,  411,   10,   60, 2117,    8,
#            62,   88,   17,   66, 1180, 1952,  447,   82,    5,   48,  130,
#             3,  308,  590]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([63, 14]),
#   'rating_inv': array([63, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7010c9': {'claim': array([  340,     8,     3,   384,   355,     3,   427,    10,  2966,
#              6,  2090,    10,  1934,   241,     5,   329, 20424]),
#   'claim_inv': array([ 340,    8,    3,  384,  355,    3,  427,   10, 2966,    6, 2090,
#            10, 1934,  241,    5,  329]),
#   'claim_oov': array([20424]),
#   'isFake': False,
#   'rating': array([373]),
#   'rating_inv': array([373]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d70341e': {'claim': array([  322,  1227,     8,    42,     2,   210,   693,   114,     9,
#            339,     1,   533,  8312, 14817,     4,  3465,  1423]),
#   'claim_inv': array([  322,  1227,     8,    42,     2,   210,   693,   114,     9,
#            339,     1,   533,  8312, 14817,     4,  3465,  1423]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([31, 14]),
#   'rating_inv': array([31, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fe1fe': {'claim': array([    1,  1736,     8,  1147,     1,   477, 12923,     2,     1,
#            378,   781,    27,    41, 22924]),
#   'claim_inv': array([    1,  1736,     8,  1147,     1,   477, 12923,     2,     1,
#            378,   781,    27,    41, 22924]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d70129c': {'claim': array([   20,  5897,    80, 16624,    23,   131,    54,  7290,     6,
#            832,     2, 20438,    16,    22,   452,     4,   131,  1051,
#             18,  1102, 14047,    57,   775,    33,   611,     5,   655,
#           1697]),
#   'claim_inv': array([   20,  5897,    80, 16624,    23,   131,    54,  7290,     6,
#            832,     2, 20438,    16,    22,   452,     4,   131,  1051,
#             18,  1102, 14047,    57,   775,    33,   611,     5,   655,
#           1697]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([876]),
#   'rating_inv': array([0]),
#   'rating_oov': array([876])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f8ec2': {'claim': array([  47, 1217, 5453, 4010,   15, 4011,   71,    6, 5859,    1,  963]),
#   'claim_inv': array([  47, 1217, 5453, 4010,   15, 4011,   71,    6, 5859,    1,  963]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f58a0': {'claim': array([12405,   524,   606,   114,    15,  2269]),
#   'claim_inv': array([ 524,  606,  114,   15, 2269]),
#   'claim_oov': array([12405]),
#   'isFake': True,
#   'rating': array([92]),
#   'rating_inv': array([0]),
#   'rating_oov': array([92])},
#  '8907eae5-7ef2-4c1a-7507-16da7d703cd0': {'claim': array([  89,    1,  312, 4597,  225,  236,   10, 1636, 5166,  297, 5523,
#          5734]),
#   'claim_inv': array([  89,    1,  312, 4597,  225,  236,   10, 1636, 5166,  297, 5523,
#          5734]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ffcc5': {'claim': array([    3,   268,    25,  1956,     3,  3649,   628,   101,  5092,
#            350,     6,   496,     4,  4951,   137,   253,    36, 23801,
#            496,    30,  4951,   201,    36]),
#   'claim_inv': array([   3,  268,   25, 1956,    3, 3649,  628,  101, 5092,  350,    6,
#           496,    4, 4951,  137,  253,   36,  496,   30, 4951,  201,   36]),
#   'claim_oov': array([23801]),
#   'isFake': False,
#   'rating': array([343]),
#   'rating_inv': array([343]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fb558': {'claim': array([3833, 5167, 1018, 1567]),
#   'claim_inv': array([5167, 1018, 1567]),
#   'claim_oov': array([3833]),
#   'isFake': True,
#   'rating': array([1471, 1315]),
#   'rating_inv': array([1471, 1315]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fc5b5': {'claim': array([   25,   444,    28,     8,  1599, 10395,     9,    39,  1413,
#              4, 16825,    60,   120,    39,   181,     9,   163, 30089,
#             80,    39,  2723,     3,     1,  1618,    15,    10,    60,
#            120,     6,    97,  1145,     1,  3060,     3,    60,   284]),
#   'claim_inv': array([   25,   444,    28,     8,  1599, 10395,     9,    39,  1413,
#              4, 16825,    60,   120,    39,   181,     9,   163, 30089,
#             80,    39,  2723,     3,     1,  1618,    15,    10,    60,
#            120,     6,    97,  1145,     1,  3060,     3,    60,   284]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6ff958': {'claim': array([   30, 23620, 23621,  2080,    87,   375,     4,  1124,   358,
#             65,  1512,    70,    82,  1686,  3784,     4,   204,   332,
#             60,   124,   317]),
#   'claim_inv': array([   30, 23620, 23621,  2080,    87,   375,     4,  1124,   358,
#             65,  1512,    70,    82,  1686,  3784,     4,   204,   332,
#             60,   124,   317]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([31, 14]),
#   'rating_inv': array([31, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f85e2': {'claim': array([   1,  520,    2,  543,   55,    9,   69, 5516,   33,  309,   30,
#           810,  275,   49,  164,    3,    1, 1034]),
#   'claim_inv': array([   1,  520,    2,  543,   55,    9,   69, 5516,   33,  309,   30,
#           810,  275,   49,  164,    3,    1, 1034]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([249]),
#   'rating_inv': array([249]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f6503': {'claim': array([  17,  503,   23, 1102,    5, 2602,  284,   78,   25,  288,  285,
#             4,  492,   78,   25,  413,    6,   60,  513,    5,    6, 1836,
#           284,  503,   85,   20, 9073,   88]),
#   'claim_inv': array([  17,  503,   23, 1102,    5, 2602,  284,   78,   25,  288,  285,
#             4,  492,   78,   25,  413,    6,   60,  513,    5,    6, 1836,
#           284,  503,   85,   20, 9073,   88]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([31, 14]),
#   'rating_inv': array([31, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d7035d3': {'claim': array([ 439, 3949,  143, 2473,    4, 2638,   60,  227]),
#   'claim_inv': array([ 439, 3949,  143, 2473,    4, 2638,   60,  227]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d701346': {'claim': array([   93,  1678,    30,    28,   797,   195,    16,   215,    52,
#             25,   549,     1,  2539,     9,   416,   135,   151,  2793,
#              6, 11173,     9, 15468,  1904,    23,   166,   112,    20,
#           1925,     5,  3127,  2254,   847, 15469,    41,   130,  3465,
#             85,     1,   989,     6,   493,     1,  7611,     2,     1,
#           2839,   305]),
#   'claim_inv': array([   93,  1678,    30,    28,   797,   195,    16,   215,    52,
#             25,   549,     1,  2539,     9,   416,   135,   151,  2793,
#              6, 11173,     9, 15468,  1904,    23,   166,   112,    20,
#           1925,     5,  3127,  2254,   847, 15469,    41,   130,  3465,
#             85,     1,   989,     6,   493,     1,  7611,     2,     1,
#           2839,   305]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([31, 14]),
#   'rating_inv': array([31, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7902': {'claim': array([   1,  439,  820,   69,  545, 1543,  378, 2313, 3063,  394, 1222]),
#   'claim_inv': array([   1,  439,  820,   69,  545, 1543,  378, 2313, 3063,  394, 1222]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([7]),
#   'rating_inv': array([7]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d703054': {'claim': array([ 157,  744,  879,   17,   19, 8287,    1,  407,    2,   34,   35,
#           424,   54, 2073,   80,    8,   34,   35,    1,  462,  557, 4665,
#          2765,    3,   67,  113,   48,  689]),
#   'claim_inv': array([ 157,  744,  879,   17,   19, 8287,    1,  407,    2,   34,   35,
#           424,   54, 2073,   80,    8,   34,   35,    1,  462,  557, 4665,
#          2765,    3,   67,  113,   48,  689]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([14]),
#   'rating_inv': array([14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6fa3b7': {'claim': array([   68,  6371,    68,    66,  1370,    71,    68,  8857,     5,
#           4116,     6,  1252,   383,    23,     1,   124,   121,   809,
#          10190,   177,     9,     1,  1355,     4,     1,  1564,    23,
#            287,   319,     4,   287,   299]),
#   'claim_inv': array([   68,  6371,    68,    66,  1370,    71,    68,  8857,     5,
#           4116,     6,  1252,   383,    23,     1,   124,   121,   809,
#          10190,   177,     9,     1,  1355,     4,     1,  1564,    23,
#            287,   319,     4,   287,   299]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([863]),
#   'rating_inv': array([0]),
#   'rating_oov': array([863])},
#  '8907eae5-7ef2-4c1a-7507-16da7d701a4c': {'claim': array([  47,    1,  453,   90,  318, 3489,  518,  220,   42,    3,   80,
#             5,  230,  341,  151,  655,    6,  276,  341,  151,  387, 1768,
#          1854,  151, 2069,   24,  415]),
#   'claim_inv': array([  47,    1,  453,   90,  318, 3489,  518,  220,   42,    3,   80,
#             5,  230,  341,  151,  655,    6,  276,  341,  151,  387, 1768,
#          1854,  151, 2069,   24,  415]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([63, 14]),
#   'rating_inv': array([63, 14]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6f7c08': {'claim': array([  68,  200, 8851,   76,   12, 1672, 3861,    6,   41,  862,    1,
#           132, 1672]),
#   'claim_inv': array([  68,  200, 8851,   76,   12, 1672, 3861,    6,   41,  862,    1,
#           132, 1672]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([573]),
#   'rating_inv': array([0]),
#   'rating_oov': array([573])},
#  '8907eae5-7ef2-4c1a-7507-16da7d700dcc': {'claim': array([   1, 1887,  195,   12, 4730,   32, 4111,  634,   27,   16,    8,
#           571, 7326,   11, 3461,  470, 1593,    6, 4418]),
#   'claim_inv': array([   1, 1887,  195,   12, 4730,   32, 4111,  634,   27,   16,    8,
#           571, 7326,   11, 3461,  470, 1593,    6, 4418]),
#   'claim_oov': array([0]),
#   'isFake': True,
#   'rating': array([5611]),
#   'rating_inv': array([5611]),
#   'rating_oov': array([0])},
#  '8907eae5-7ef2-4c1a-7507-16da7d6faa6c': {'claim': array([   10,     1,    96,    98,   116,     1,   936,  1155,     1,
#          11316,  3040,    20]),
#   'claim_inv': array([   10,     1,    96,    98,   116,     1,   936,  1155,     1,
#          11316,  3040,    20]),
#   'claim_oov': array([0]),
#   'isFake': False,
#   'rating': array([46]),
#   'rating_inv': array([46]),
#   'rating_oov': array([0])},
#  ...}

# %%
for ID in partition['rated']:
    q = '''
        USE FactMap;

        SELECT r.*
        FROM reviews r
        WHERE r.uid = uuid('{0}');
        '''.format(ID)
    output = con.query(q).results[0]
    output['reviewRating']['isFake'] = partition['rated'][ID]['isFake']
    
    reviews.append(output)

# %%
for i in range(len(gen_unrated)):
    ID = gen_unrated.__getitem__(i)[0][0]
    q = '''
        USE FactMap;

        SELECT r.*
        FROM reviews r
        WHERE r.uid = uuid('{}');
        '''.format(ID)
    output = con.query(q).results[0]
    
    pred = predict(model=rnn_single, generator=gen_unrated, item=i)
    output['reviewRating'].update(pred)
    
    reviews.append(output)

# %% [markdown]
# Output all reviews to json:

# %%
path = "/Users/anders1991/Github/FactMap/Data/claimreviews/claims_rated.json"

with open(path, 'w') as f:
    f.write('\n'.join(json.dumps(r) for r in reviews))

# %% [markdown]
# Replace reviews dataset with rated reviews in Asterix (the non-optimal way – inserting each rating individually is actually slower due to I/O overhead):

# %%
response = con.query('''
    USE FactMap;
    
    SET `compiler.joinmemory` "128MB";
    
    DROP DATASET urljoin IF EXISTS;
    DROP DATASET fuzzyurljoin IF EXISTS;
    DROP DATASET facturljoin IF EXISTS;
    DROP TYPE PostReviewType IF EXISTS;
    
    DROP DATASET reviews IF EXISTS;
    DROP TYPE ReviewType IF EXISTS;
    
    CREATE TYPE ReviewType as {
        uid: string
    };
    CREATE DATASET reviews(ReviewType)
        PRIMARY KEY uid;
                
    LOAD DATASET reviews
    USING localfs (("path"="localhost:///Users/anders1991/Github/FactMap/Data/claimreviews/claims_rated.json"),("format"="json"));
    ''')

# %% [markdown]
# ...and rejoin datasets on URL (I warned you it would be painful! :-) ):

# %%
response = con.query('''
    USE FactMap;
    SET `compiler.joinmemory` "128MB";
    
    DROP TYPE PostReviewType IF EXISTS;
    CREATE TYPE PostReviewType as {
        r: ReviewType,
        p: SubmissionType
    };

    CREATE DATASET urljoin(PostReviewType)
        PRIMARY KEY r.uid, p.id;

    INSERT INTO urljoin
    SELECT *
    FROM posts p, reviews r
    WHERE r.claimAuthor.claimURL = p.url;
''')

# %% [markdown]
# Check results:

# %%
response = con.query('''
    USE FactMap;
    
    SELECT u.*
    FROM urljoin u;
    ''')

print('Number of matches:', len(response.results))

response = con.query('''
    USE FactMap;

    SELECT count(distinct r.uid) as c
    FROM urljoin u
    LIMIT 1;
    ''')
print('Number of unique claims:', response.results[0]['c'])
# Out:
# Number of matches: 14325
# Number of unique claims: 1652

# %% [markdown]
# Expected values are 14325 and 1652, respectively.

# %% [markdown]
# ...and rejoin datasets with additional fuzzy matching on Twitter/Wikipedia:

# %%
response = con.query('''
    USE FactMap;

    SET `compiler.joinmemory` "128MB";

    DROP DATASET fuzzyurljoin IF EXISTS;
    
    CREATE DATASET fuzzyurljoin(PostReviewType)
        PRIMARY KEY r.uid, p.id;
        
    INSERT INTO fuzzyurljoin
        SELECT u.*
        FROM urljoin u
        WHERE
            (similarity_jaccard(word_tokens(lower(p.title)), word_tokens(lower(r.claimReviewed))) > 0.20
            OR similarity_jaccard(word_tokens(lower(p.title)), word_tokens(lower(r.claimReviewed_en))) > 0.20)
            AND (abs(length(r.claimReviewed) - length(p.title)) <= 
                (array_min([length(r.claimReviewed), length(p.title)])) * 0.2)
            AND (array_min([length(r.claimReviewed), length(p.title)]) > 15)
            AND (contains(p.domain, "wikipedia") OR contains(p.domain, "twitter"));
    
    INSERT INTO fuzzyurljoin
    SELECT u.*
    FROM urljoin u
    WHERE
            (
                (edit_distance_contains(lower(p.title), lower(r.claimReviewed), length(r.claimReviewed) * 0.5)[0] 
                    OR edit_distance_contains(lower(r.claimReviewed), lower(p.title), length(p.title) * 0.5)[0])
                OR
                (edit_distance_contains(lower(p.title), lower(r.claimReviewed_en), length(r.claimReviewed_en) * 0.5)[0] 
                    OR edit_distance_contains(lower(r.claimReviewed_en), lower(p.title), length(p.title) * 0.5)[0])
            )
            AND (abs(length(r.claimReviewed) - length(p.title)) > 
                (array_min([length(r.claimReviewed), length(p.title)])) * 0.2)
            AND (array_min([length(r.claimReviewed), length(p.title)]) > 15)
            AND (contains(p.domain, "wikipedia") OR contains(p.domain, "twitter"));
    
    INSERT INTO fuzzyurljoin
    SELECT u.*
    FROM urljoin u
    WHERE NOT (contains(p.domain, "wikipedia") OR contains(p.domain, "twitter"));
    ''')

# %% [markdown]
# Check results:

# %%
response = con.query('''
    USE FactMap;
    
    SELECT COUNT(*) as total
    FROM fuzzyurljoin f;
    ''')

print('Number of matches:', response.results[0]['total'])

response = con.query('''
    USE FactMap;

    SELECT COUNT(DISTINCT r.uid) unique_claims
    FROM fuzzyurljoin f;
    ''')

print('Number of unique claims', response.results[0]['unique_claims'])
# Out:
# Number of matches: 8202
# Number of unique claims 1378

# %% [markdown]
# Expected values are 8202 and 1378, respectively.

# %% [markdown]
# Finally, we rejoin on the review URLs:

# %%
response = con.query('''
    USE FactMap;
    SET `compiler.joinmemory` "128MB";
    
    CREATE DATASET facturljoin(PostReviewType)
        PRIMARY KEY r.uid, p.id;

    INSERT INTO facturljoin
    SELECT *
    FROM posts p, reviews r
    WHERE r.reviewUrl = p.url;
''')

# %% [markdown]
# Check results:

# %%
response = con.query('''
    USE FactMap;
    
    SELECT COUNT(*) as total
    FROM facturljoin f;
    ''')

print('Number of matches:', response.results[0]['total'])

response = con.query('''
    USE FactMap;

    SELECT COUNT(DISTINCT r.uid) unique_claims
    FROM facturljoin f;
    ''')

print('Number of unique reviews', response.results[0]['unique_claims'])
# Out:
# Number of matches: 19224
# Number of unique reviews 8636

# %% [markdown]
# Expected values are 19224 and 8636, respectively.

# %% [markdown]
# ---
